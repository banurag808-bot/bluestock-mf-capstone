# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## NAV History Data Quality Assessment

# %%
nav = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\02_nav_history.csv")
nav.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %% [markdown]
# # Dataset Overview

# %%
nav.shape
# Out:
# (46000, 3)

# %%
nav.columns
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='str')

# %%
nav.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  str
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 1.1 MB

# %% [markdown]
# # Validate Date Column

# %%
nav.dtypes
# Out:
# amfi_code             int64
# date         datetime64[us]
# nav                 float64
# dtype: object

# %%
nav["date"] = pd.to_datetime(nav["date"])

# %% [markdown]
# # Missing Values Check

# %%
nav.isnull().sum()

# No missing NAV values found.
# Forward fill not required
# Out:
# amfi_code    0
# date         0
# nav          0
# dtype: int64

# %% [markdown]
# # Duplicate Check

# %%
nav.duplicated().sum()

# No duplicate records found.
# Out:
# np.int64(0)

# %% [markdown]
# # Validate NAV > 0

# %%
(nav["nav"] <= 0).sum()

# All NAV values are greater than zero.
# Out:
# np.int64(0)

# %% [markdown]
# # Sort Data

# %%
nav = nav.sort_values(
    by=["amfi_code", "date"])

# %% [markdown]
# # Save Processed File

# %%
nav.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_nav_history.csv",
    index=False)

# %% [markdown]
# # investor_transactions.csv

# %%
inv_trans = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\08_investor_transactions.csv")
inv_trans.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %% [markdown]
# # Understand Dataset

# %%
inv_trans.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32778 entries, 0 to 32777
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   investor_id         32778 non-null  str
#  1   transaction_date    32778 non-null  str
#  2   amfi_code           32778 non-null  int64
#  3   transaction_type    32778 non-null  str
#  4   amount_inr          32778 non-null  int64
#  5   state               32778 non-null  str
#  6   city                32778 non-null  str
#  7   city_tier           32778 non-null  str
#  8   age_group           32778 non-null  str
#  9   gender              32778 non-null  str
#  10  annual_income_lakh  32778 non-null  float64
#  11  payment_mode        32778 non-null  str
#  12  kyc_status          32778 non-null  str
# dtypes: float64(1), int64(2), str(10)
# memory usage: 3.3 MB

# %%
inv_trans.dtypes
# Out:
# investor_id                      str
# transaction_date      datetime64[us]
# amfi_code                      int64
# transaction_type                 str
# amount_inr                     int64
# state                            str
# city                             str
# city_tier                        str
# age_group                        str
# gender                           str
# annual_income_lakh           float64
# payment_mode                     str
# kyc_status                       str
# dtype: object

# %% [markdown]
# # Fix Date Formats

# %%
inv_trans["transaction_date"] = pd.to_datetime(inv_trans["transaction_date"])

# %%
inv_trans.dtypes
# Out:
# investor_id                      str
# transaction_date      datetime64[us]
# amfi_code                      int64
# transaction_type                 str
# amount_inr                     int64
# state                            str
# city                             str
# city_tier                        str
# age_group                        str
# gender                           str
# annual_income_lakh           float64
# payment_mode                     str
# kyc_status                       str
# dtype: object

# %% [markdown]
# # Standardise transaction_type

# %%
inv_trans["transaction_type"].value_counts()
# Out:
# transaction_type
# SIP           19716
# LUMPSUM        8095
# REDEMPTION     4967
# Name: count, dtype: int64

# %%
inv_trans["transaction_type"] = (inv_trans["transaction_type"].str.strip().str.upper())

# %% [markdown]
# # Validate Amount > 0

# %%
(inv_trans["amount_inr"] <= 0).sum()

# all amount greater than zero
# Out:
# np.int64(0)

# %% [markdown]
# # Check KYC Status

# %%
inv_trans["kyc_status"].value_counts()
# Out:
# kyc_status
# Verified    30146
# Pending      2632
# Name: count, dtype: int64

# %% [markdown]
# # Check Missing Values

# %%
inv_trans.isnull().sum()
# Out:
# investor_id           0
# transaction_date      0
# amfi_code             0
# transaction_type      0
# amount_inr            0
# state                 0
# city                  0
# city_tier             0
# age_group             0
# gender                0
# annual_income_lakh    0
# payment_mode          0
# kyc_status            0
# dtype: int64

# %% [markdown]
# # Duplicate Check

# %%
inv_trans.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Save Cleaned File

# %%
inv_trans.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_investor_transactions.csv",index=False)

# %% [markdown]
# # Scheme Performance Dataset

# %%
sch_perf = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\07_scheme_performance.csv")

# %%
sch_perf.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %% [markdown]
# # Validate Datatype

# %%
sch_perf.dtypes

# return column values already in numeric type
# Out:
# amfi_code               int64
# scheme_name               str
# fund_house                str
# category                  str
# plan                      str
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade                str
# dtype: object

# %% [markdown]
# # Flag Negative Sharp Ratio

# %%
(sch_perf["sharpe_ratio"] < 0).sum()

# No negative Sharpe Ratios found.
# No flagging is required
# Out:
# np.int64(0)

# %% [markdown]
# # Validate Expense Ratio

# %%
sch_perf["expense_ratio_pct"].describe()

# all expense ratio pct is within a desired range (0.1% - 2.5%)
# Out:
# count    40.000000
# mean      1.237000
# std       0.386584
# min       0.550000
# 25%       0.787500
# 50%       1.425000
# 75%       1.540000
# max       1.640000
# Name: expense_ratio_pct, dtype: float64

# %% [markdown]
# # Check Missing Values

# %%
sch_perf.isnull().sum()
# Out:
# amfi_code             0
# scheme_name           0
# fund_house            0
# category              0
# plan                  0
# return_1yr_pct        0
# return_3yr_pct        0
# return_5yr_pct        0
# benchmark_3yr_pct     0
# alpha                 0
# beta                  0
# sharpe_ratio          0
# sortino_ratio         0
# std_dev_ann_pct       0
# max_drawdown_pct      0
# aum_crore             0
# expense_ratio_pct     0
# morningstar_rating    0
# risk_grade            0
# dtype: int64

# %% [markdown]
# # Duplicate Check

# %%
sch_perf.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Save Cleaned Dataset

# %%
sch_perf.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_scheme_performance.csv",index=False)

# %% [markdown]
# # Fund Master Dataset

# %%
fund_master = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\01_fund_master.csv")

# %%
fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %% [markdown]
# # Perform Checks

# %%
fund_master.shape
# Out:
# (40, 15)

# %%
fund_master.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     str
#  2   scheme_name         40 non-null     str
#  3   category            40 non-null     str
#  4   sub_category        40 non-null     str
#  5   plan                40 non-null     str
#  6   launch_date         40 non-null     str
#  7   benchmark           40 non-null     str
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     str
#  13  risk_category       40 non-null     str
#  14  sebi_category_code  40 non-null     str
# dtypes: float64(2), int64(3), str(10)
# memory usage: 4.8 KB

# %%
fund_master.isnull().sum()
# Out:
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64

# %%
fund_master.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Validate

# %%
fund_master["risk_category"].unique()
# Out:
# <StringArray>
# ['Moderate', 'Very High', 'Low', 'High', 'Moderately High']
# Length: 5, dtype: str

# %%
fund_master["category"].unique()
# Out:
# <StringArray>
# ['Equity', 'Debt']
# Length: 2, dtype: str

# %%
fund_master["sub_category"].unique()
# Out:
# <StringArray>
# [      'Large Cap',       'Small Cap',            'Gilt',         'Mid Cap',
#   'Short Duration',           'Value',          'Liquid',       'Index/ETF',
#        'Flexi Cap',           'Index', 'Large & Mid Cap',            'ELSS']
# Length: 12, dtype: str

# %%
fund_master["expense_ratio_pct"].describe()
# Out:
# count    40.000000
# mean      1.237000
# std       0.386584
# min       0.550000
# 25%       0.787500
# 50%       1.425000
# 75%       1.540000
# max       1.640000
# Name: expense_ratio_pct, dtype: float64

# %%
fund_master["amfi_code"].nunique()
# Out:
# 40

# %% [markdown]
# # Save Cleaned Dataset

# %%
fund_master.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_fund_master.csv",index=False)

# %% [markdown]
# # aum by fund house dataset

# %%
aum_fund = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\03_aum_by_fund_house.csv")

# %%
aum_fund.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
aum_fund.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            90 non-null     datetime64[us]
#  1   fund_house      90 non-null     str
#  2   aum_lakh_crore  90 non-null     float64
#  3   aum_crore       90 non-null     int64
#  4   num_schemes     90 non-null     int64
# dtypes: datetime64[us](1), float64(1), int64(2), str(1)
# memory usage: 3.6 KB

# %%
aum_fund.isnull().sum()
# Out:
# date              0
# fund_house        0
# aum_lakh_crore    0
# aum_crore         0
# num_schemes       0
# dtype: int64

# %%
aum_fund["date"] = pd.to_datetime(aum_fund["date"])

# %%
aum_fund.duplicated().sum()
# Out:
# np.int64(0)

# %%
aum_fund.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_aum_by_fund_house.csv",index=False)

# %% [markdown]
# # monthly sip inflows dataset

# %%
sip_monthly = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\04_monthly_sip_inflows.csv")

# %%
sip_monthly.head()
# Out:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
sip_monthly.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      48 non-null     datetime64[us]
#  1   sip_inflow_crore           48 non-null     int64
#  2   active_sip_accounts_crore  48 non-null     float64
#  3   new_sip_accounts_lakh      48 non-null     float64
#  4   sip_aum_lakh_crore         48 non-null     float64
#  5   yoy_growth_pct             36 non-null     float64
# dtypes: datetime64[us](1), float64(4), int64(1)
# memory usage: 2.4 KB

# %%
sip_monthly["month"] = pd.to_datetime(sip_monthly["month"])

# %%
sip_monthly.isnull().sum()

# yoy_growth_pct contains 12 null values.

# These values occur because prior-year data is unavailable for the first 12 months of the dataset.

# The values were retained as NULL since Year-over-Year growth cannot be calculated.
# Out:
# month                         0
# sip_inflow_crore              0
# active_sip_accounts_crore     0
# new_sip_accounts_lakh         0
# sip_aum_lakh_crore            0
# yoy_growth_pct               12
# dtype: int64

# %%
sip_monthly.duplicated().sum()
# Out:
# np.int64(0)

# %%
sip_monthly.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_monthly_sip_inflows.csv",index=False)

# %% [markdown]
# # Category Inflows Dataset

# %%
category = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\05_category_inflows.csv")

# %%
category.head()
# Out:
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
category.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             144 non-null    datetime64[us]
#  1   category          144 non-null    str
#  2   net_inflow_crore  144 non-null    float64
# dtypes: datetime64[us](1), float64(1), str(1)
# memory usage: 3.5 KB

# %%
category["month"] = pd.to_datetime(category["month"])

# %%
category.isnull().sum()
# Out:
# month               0
# category            0
# net_inflow_crore    0
# dtype: int64

# %%
category.duplicated().sum()
# Out:
# np.int64(0)

# %%
category.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_category_inflows.csv",index=False)

# %% [markdown]
# # Industry Folio Count Dataset

# %%
industry = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\06_industry_folio_count.csv")

# %%
industry.head()
# Out:
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
industry.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                21 non-null     datetime64[us]
#  1   total_folios_crore   21 non-null     float64
#  2   equity_folios_crore  21 non-null     float64
#  3   debt_folios_crore    21 non-null     float64
#  4   hybrid_folios_crore  21 non-null     float64
#  5   others_folios_crore  21 non-null     float64
# dtypes: datetime64[us](1), float64(5)
# memory usage: 1.1 KB

# %%
industry["month"] = pd.to_datetime(industry["month"])

# %%
industry.isnull().sum()
# Out:
# month                  0
# total_folios_crore     0
# equity_folios_crore    0
# debt_folios_crore      0
# hybrid_folios_crore    0
# others_folios_crore    0
# dtype: int64

# %%
industry.duplicated().sum()
# Out:
# np.int64(0)

# %%
industry.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_industry_folio_count.csv",index=False)

# %% [markdown]
# # Portfolio Holdings Dataset

# %%
portfolio = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\09_portfolio_holdings.csv")

# %%
portfolio.head()
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
portfolio.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   amfi_code          322 non-null    int64
#  1   stock_symbol       322 non-null    str
#  2   stock_name         322 non-null    str
#  3   sector             322 non-null    str
#  4   weight_pct         322 non-null    float64
#  5   market_value_cr    322 non-null    float64
#  6   current_price_inr  322 non-null    float64
#  7   portfolio_date     322 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(3), int64(1), str(3)
# memory usage: 20.3 KB

# %%
portfolio["portfolio_date"] = pd.to_datetime(portfolio["portfolio_date"])

# %%
portfolio.isnull().sum()
# Out:
# amfi_code            0
# stock_symbol         0
# stock_name           0
# sector               0
# weight_pct           0
# market_value_cr      0
# current_price_inr    0
# portfolio_date       0
# dtype: int64

# %%
portfolio.duplicated().sum()
# Out:
# np.int64(0)

# %%
portfolio.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_portfolio_holdings.csv",index=False)

# %% [markdown]
# # Benchmark Indices

# %%
benchmark = pd.read_csv(r"D:\bluestock_mf_capstone\data\raw\10_benchmark_indices.csv")

# %%
benchmark.head()
# Out:
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
benchmark.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8050 entries, 0 to 8049
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         8050 non-null   datetime64[us]
#  1   index_name   8050 non-null   str
#  2   close_value  8050 non-null   float64
# dtypes: datetime64[us](1), float64(1), str(1)
# memory usage: 188.8 KB

# %%
benchmark["date"] = pd.to_datetime(benchmark["date"])

# %%
benchmark.isnull().sum()
# Out:
# date           0
# index_name     0
# close_value    0
# dtype: int64

# %%
benchmark.duplicated().sum()
# Out:
# np.int64(0)

# %%
benchmark.to_csv(r"D:\bluestock_mf_capstone\data\processed/clean_benchmark_indices.csv",index=False)
